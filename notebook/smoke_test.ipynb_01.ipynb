# %%
import pandas as pd

df = pd.read_csv("../Data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#    product_id  price  quantity
# 0         101  15.50        10
# 1         102  20.00         5
# 2         103   7.25        20
# 3         104  50.00         2
# 4         105  12.00         8
#        product_id      price   quantity
# count    5.000000   5.000000   5.000000
# mean   103.000000  20.950000   9.000000
# std      1.581139  16.898964   6.855655
# min    101.000000   7.250000   2.000000
# 25%    102.000000  12.000000   5.000000
# 50%    103.000000  15.500000   8.000000
# 75%    104.000000  20.000000  10.000000
# max    105.000000  50.000000  20.000000
